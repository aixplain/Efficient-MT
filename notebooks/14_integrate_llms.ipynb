# %%
# MQM Categories
# 0: "Accuracy",
# 1: "Fluency",§
# 2: "Locale convention",
# 3: "No-error",
# 4: "Other",
# 5: "Terminology",

# %%
import sys

sys.path.append("../")

from gemba.CREDENTIALS import credentials
from gemba.prompt import prompts, language_codes
from gemba.gpt_api import GptApi
from gemba.cache import Cache

gptapi = GptApi(credentials, verbose=False)

use_model = "GPT-4"
annotation = "GEMBA-DA"
cache = Cache(f"{use_model}_{annotation}.jsonl")

# %%
def get_translation_quality(src, hyp, src_lng="en", trg_lng="de", ref=None):
    lng = "en-de"
    if prompts[annotation]["use_ref"] and ref is None:
        raise ValueError("Reference is required for this metric")

    data = {
        "source_seg": src,
        "target_seg": hyp,
        "reference_seg": ref,
        "source_lang": src_lng,
        "target_lang": trg_lng,
    }
    prompt = prompts[annotation]["prompt"].format(**data)
    parsed_answers = gptapi.request(
        prompt, use_model, prompts[annotation]["validate_answer"], cache=cache
    )
    return parsed_answers[0]["answer"]

# %%
get_translation_quality("This is a test", "Dies ist ein Test")
# Out:
# 100

# %% [markdown]
# ## MQM

# %%
from gemba.gemba_mqm_utils import (
    TEMPLATE_GEMBA_MQM_ENDE,
    TEMPLATE_GEMBA_MQM,
    apply_template,
    parse_mqm_answer,
)
from collections import defaultdict

# %%
use_model = "GPT-4"
cache = Cache(f"{use_model}_GEMBA-MQM.jsonl")

# %%
def get_mqm_erros(src, hyp, src_lng="en", trg_lng="de", ref=None):
    use_model = "GPT-4"
    cache = Cache(f"{use_model}_GEMBA-MQM.jsonl")
    data = {
        "source_seg": src,
        "target_seg": hyp,
        "source_lang": src_lng,
        "target_lang": trg_lng,
    }
    prompt = apply_template(TEMPLATE_GEMBA_MQM, data)
    parsed_answers = gptapi.request(
        prompt,
        use_model,
        lambda x: parse_mqm_answer(x, list_mqm_errors=True, full_desc=False),
        cache=cache,
    )

    errors = defaultdict(list)
    errors.update(parsed_answers[0]["answer"])
    error_list = errors["minor"] + errors["major"] + errors["critical"]

    return error_list

# %%
src = (
    "According to the British government's "
    "reasonable worst-case"
    " scenario, the flow of goods could be cut by half on Day One of a no-deal Brexit and could take a year to recover. It said time was "
    "extremely limited "
    " if the shipping issues were to be resolved by the end of October."
)
hyp = "Laut dem „vernünftigen Worst-Case“ -Szenario der britischen Regierung könnte der Warenfluss am ersten Tag eines No-Deal-Brexits um die Hälfte reduziert werden und könnte ein Jahr dauern, um sich zu erholen. Es hieß, die Zeit sei „extrem begrenzt“, wenn die Schifffahrtsprobleme bis Ende Oktober gelöst werden sollten."
src_lng = "en"
trg_lng = "de"

get_mqm_erros(src, hyp, src_lng, trg_lng)
# Out:
# ['fluency']

# %% [markdown]
# ## Suggest postedit

# %%
def get_postedit(src, hyp, src_lng="en", trg_lng="de", ref=None):
    use_model = "GPT-4"
    annotation = "POSTEDIT"
    cache = Cache(f"{use_model}_{annotation}.jsonl")
    data = {
        "source_seg": src,
        "target_seg": hyp,
        "source_lang": src_lng,
        "target_lang": trg_lng,
    }
    prompt = prompts[annotation]["prompt"].format(**data)
    parsed_answers = gptapi.request(
        prompt, use_model, prompts[annotation]["validate_answer"], cache=cache
    )
    return parsed_answers[0]["answer"]
# Out:
# Saving cache GPT-4_GEMBA-MQM.jsonl

# %%
src = (
    "According to the British government's "
    "reasonable worst-case"
    " scenario, the flow of goods could be cut by half on Day One of a no-deal Brexit and could take a year to recover. It said time was "
    "extremely limited "
    " if the shipping issues were to be resolved by the end of October."
)
hyp = "Laut dem „vernünftigen Worst-Case“ -Szenario der britischen Regierung könnte der Warenfluss am ersten Tag eines No-Deal-Brexits um die Hälfte reduziert werden und könnte ein Jahr dauern, um sich zu erholen. Es hieß, die Zeit sei „extrem begrenzt“, wenn die Schifffahrtsprobleme bis Ende Oktober gelöst werden sollten."
src_lng = "en"
trg_lng = "de"

get_postedit(src, hyp, src_lng, trg_lng)
# Out:
# '"Laut dem „vernünftigen Worst-Case“-Szenario der britischen Regierung könnte der Warenfluss am ersten Tag eines No-Deal-Brexits um die Hälfte reduziert werden und es könnte ein Jahr dauern, bis er sich erholt. Es wurde gesagt, dass die Zeit extrem begrenzt sei, wenn die Probleme mit dem Warenverkehr bis Ende Oktober gelöst werden sollten."'

# %% [markdown]
# ## Find the best translation

# %%
from gemba.prompt import get_best_translation_propmt
import pandas as pd


df = pd.read_csv(
    "/home/ubuntu/repos/Efficient-MT/data/wmt_2020_all_reduced_system_class_updated.csv"
)
df_seg = df[df.seg_id == 6]

# %%
df_seg
# Out:
#     seg_id system sample_id  \
# 10       6   MT A       6_6
# 11       6   MT B       6_6
# 12       6   MT C       6_6
# 13       6   MT D       6_6
# 14       6   MT E       6_6
# 15       6   MT F       6_6
# 16       6   MT G       6_6
# 17       6   MT H       6_6
# 18       6   MT I       6_6
# 19       6   MT J       6_6
#
#                                                source  \
# 10  He knew how to manipulate the media. He knew e...
# 11  He knew how to manipulate the media. He knew e...
# 12  He knew how to manipulate the media. He knew e...
# 13  He knew how to manipulate the media. He knew e...
# 14  He knew how to manipulate the media. He knew e...
# 15  He knew how to manipulate the media. He knew e...
# 16  He knew how to manipulate the media. He knew e...
# 17  He knew how to manipulate the media. He knew e...
# 18  He knew how to manipulate the media. He knew e...
# 19  He knew how to manipulate the media. He knew e...
#
#                                                target  \
# 10  „Er wusste, wie er die Medien manipulieren kon...
# 11  „Er wusste, wie man die Medien manipuliert. Er...
# 12  Der ein Jahrzehnt als Leibwächter Jacksons tät...
# 13  „Er wusste, wie man die Medien manipuliert. Er...
# 14  „Er wusste, wie man die Medien manipuliert. Er...
# 15  "Er wusste, wie man die Medien manipuliert. Er...
# 16  "Er wusste, wie man die Medien manipuliert. Er...
# 17  „Er wusste, wie man die Medien manipuliert. Er...
# 18  "Er wusste, wie man die Medien manipuliert. Er...
# 19  „Er wusste, wie man die Medien manipuliert. Er...
#
#                                            category severity  \
# 10                 ['Other', 'Accuracy', 'Fluency']     Edit
# 11          ['No-error', 'Accuracy', 'Terminology']     Edit
# 12              ['Other', 'Terminology', 'Fluency']     Edit
# 13  ['Other', 'Accuracy', 'Terminology', 'Fluency']     Edit
# 14  ['Other', 'Accuracy', 'Terminology', 'Fluency']     Edit
# 15                 ['Other', 'Accuracy', 'Fluency']     Edit
# 16  ['Other', 'Accuracy', 'Terminology', 'Fluency']     Edit
# 17  ['Other', 'Accuracy', 'Terminology', 'Fluency']     Edit
# 18                 ['Other', 'Accuracy', 'Fluency']     Edit
# 19  ['Other', 'Accuracy', 'Terminology', 'Fluency']     Edit
#
#              source_topic           target_topic  Num token  ...  \
# 10  Politics & Government                Unknown        4.6  ...
# 11  Politics & Government                Unknown        1.0  ...
# 12  Politics & Government  Politics & Government        2.0  ...
# 13  Politics & Government  Entertainment & Music       -3.0  ...
# 14  Politics & Government  Entertainment & Music       -3.0  ...
# 15  Politics & Government  Entertainment & Music        1.0  ...
# 16  Politics & Government  Entertainment & Music       -4.0  ...
# 17  Politics & Government  Entertainment & Music       -4.0  ...
# 18  Politics & Government  Entertainment & Music       -4.0  ...
# 19  Politics & Government  Entertainment & Music       -1.0  ...
#
#     Num PronType=Tot  Num Style=Arch  Num Style=Coll  \
# 10               0.0             0.0             0.0
# 11               0.0             0.0             0.0
# 12               0.0             0.0             0.0
# 13               0.0             0.0             0.0
# 14               0.0             0.0             0.0
# 15               0.0             0.0             0.0
# 16               0.0             0.0             0.0
# 17               0.0             0.0             0.0
# 18               0.0             0.0             0.0
# 19               0.0             0.0             0.0
#
#     COMET_QE, cased, punctuated  COMET_QE, cased, not punctuated  \
# 10                      0.22834                          0.00456
# 11                      0.27350                          0.00000
# 12                      0.34750                          0.30070
# 13                      0.10630                          0.00000
# 14                      0.18290                          0.00000
# 15                      0.00000                          0.00000
# 16                      0.00000                          0.00000
# 17                      0.18300                          0.00000
# 18                      0.00000                          0.00000
# 19                      0.06760                          0.00000
#
#     COMET_QE, uncased, punctuated  COMET_QE, uncased, not punctuated   CLSSS  \
# 10                        0.00002                                0.0  83.698
# 11                        0.00040                                0.0  84.780
# 12                        0.05640                                0.0  81.510
# 13                        0.00220                                0.0  85.700
# 14                        0.00020                                0.0  84.560
# 15                        0.00000                                0.0   0.000
# 16                        0.00000                                0.0   0.000
# 17                        0.00020                                0.0  84.270
# 18                        0.00000                                0.0   0.000
# 19                        0.00000                                0.0  85.265
#
#     topic_distance  labse_distance
# 10        0.102242        0.118060
# 11        0.108665        0.101280
# 12        0.074739        0.158790
# 13        0.151780        0.095097
# 14        0.127199        0.100404
# 15        0.120956        0.108549
# 16        0.131539        0.105066
# 17        0.125635        0.101808
# 18        0.131888        0.113470
# 19        0.137343        0.101926
#
# [10 rows x 137 columns]

# %%
src = df_seg["source"].values[0]
mts = df_seg["target"].values.tolist()
src_lng = "en"
trg_lng = "de"

# %%
def select_best(src, mts, src_lng="en", trg_lng="de"):
    prompt = get_best_translation_propmt(src, mts, src_lng, trg_lng)
    parsed_answers = gptapi.request(prompt, use_model, lambda x: int(x), cache=cache)
    return parsed_answers[0]["answer"]

# %%
select_best(src, mts, src_lng, trg_lng)
# Out:
# 1
